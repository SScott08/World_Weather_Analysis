# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
# vacation_df = pd.read_csv("Vacation_Search/WeatherPy_vacation.csv")
# vacation_df.head()
city_data_df = pd.read_csv("WeatherPy_vacation.csv")
city_data_df.head(40)
# Out:
#                city country  temperature       description  latitude  \
# 0        bredasdorp      ZA        60.80         clear sky    -34.53
# 1         bhitarwar      IN        84.20  scattered clouds     25.80
# 2           baculin      PH        79.43   overcast clouds      7.45
# 3              esil      KZ        50.14         clear sky     51.96
# 4    saint-philippe      RE        69.80              mist    -21.36
# 5   arraial do cabo      BR        80.60        few clouds    -22.97
# 6          klaksvik      FO        51.80           drizzle     62.23
# 7         shubarshi      KZ        64.13         clear sky     48.59
# 8     makakilo city      US        78.80   overcast clouds     21.35
# 9             dubbo      AU        53.60         clear sky    -32.25
# 10           hobart      AU        60.01   overcast clouds    -42.88
# 11     puerto ayora      EC        77.00  scattered clouds     -0.74
# 12          college      US        53.60     broken clouds     64.86
# ...

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = info_box_template = """
<dl>
<dt>name</dt><dd>{Hotel Name}<dd>
<dt>city</dt><dd>{city}</dd>
<dt>country</dt><dd>{country}</dd>
<dt>description</dt><dd>{description}</dd>
<dt>temperature</dt><dd>{temperature}</dd>
</dl>
"""


# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in city_data_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = city_data_df[["latitude", "longitude"]]

# %%
# 4a. Add a marker layer for each city to the map.
fig=gmaps.figure()
locations = city_data_df[["latitude", "longitude"]]
max_temp = city_data_df[["temperature"]]
description = city_data_df[["description"]]
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(marker_layer)


# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = city_data_df.loc[city_data_df["city"]=="college"]
vacation_end = city_data_df.loc[city_data_df["city"]=="college"]
vacation_stop1 = city_data_df.loc[city_data_df["city"]=="laguna"]
vacation_stop2 = city_data_df.loc[city_data_df["city"]=="jamestown"] 
vacation_stop3 = city_data_df.loc[city_data_df["city"]=="goderich"]

# %%
print(vacation_stop2)
# Out:
#            city country  temperature description  latitude  longitude  \
# 25    jamestown      US        66.99  few clouds      42.1     -79.24
# 120   jamestown      US        66.99  few clouds      42.1     -79.24
# 124   jamestown      US        66.99  few clouds      42.1     -79.24
# 176   jamestown      US        66.99  few clouds      42.1     -79.24
# 249   jamestown      US        66.99  few clouds      42.1     -79.24
# 312   jamestown      US        66.99  few clouds      42.1     -79.24
# 405   jamestown      US        66.99  few clouds      42.1     -79.24
# 529   jamestown      US        66.99  few clouds      42.1     -79.24
# 540   jamestown      US        66.99  few clouds      42.1     -79.24
# 548   jamestown      US        66.99  few clouds      42.1     -79.24
# 601   jamestown      US        66.99  few clouds      42.1     -79.24
# 654   jamestown      US        66.99  few clouds      42.1     -79.24
# ...

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["latitude"].values[0],vacation_start["longitude"].values[0]
end = vacation_end["latitude"].values[0],vacation_end["longitude"].values[0]
stop1 = vacation_stop1["latitude"].values[0],vacation_stop1["longitude"].values[0]
stop2 = vacation_stop2["latitude"].values[0],vacation_stop2["longitude"].values[0]
stop3 = vacation_stop3["latitude"].values[0],vacation_stop3["longitude"].values[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig=gmaps.figure()
vacation_layer = gmaps.directions_layer(start,end, waypoints =[stop1, stop2, stop3], travel_mode='DRIVING')                                      
fig.add_layer(vacation_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_end, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#             city country  temperature      description  latitude  longitude  \
# 0        college      US        53.60    broken clouds     64.86    -147.80
# 1        college      US        53.60    broken clouds     64.86    -147.80
# 2        college      US        53.60    broken clouds     64.86    -147.80
# 3        college      US        53.60    broken clouds     64.86    -147.80
# 4        college      US        53.60    broken clouds     64.86    -147.80
# 5        college      US        53.60    broken clouds     64.86    -147.80
# 6         laguna      US        93.99             haze     38.42    -121.42
# 7         laguna      US        93.99             haze     38.42    -121.42
# 8         laguna      US        93.99             haze     38.42    -121.42
# 9      jamestown      US        66.99       few clouds     42.10     -79.24
# 10     jamestown      US        66.99       few clouds     42.10     -79.24
# ...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>name</dt><dd>{Hotel Name}<dd>
<dt>city</dt><dd>{city}</dd>
<dt>country</dt><dd>{country}</dd>
<dt>description</dt><dd>{description}</dd>
<dt>temperature</dt><dd>{temperature}</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["latitude", "longitude"]]

# %%
# 11a. Add a marker layer for each city to the map.
fig=gmaps.figure()
#locations = locations[["latitude", "longitude"]]
#max_temp = locations[["temperature"]]
#description = locations[["description"]]
marker_layer = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
